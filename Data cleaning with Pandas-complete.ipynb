# %% [markdown]
#   # Data Cleaning with Pandas #

# %% [markdown]
# Welcome to your introduction to Pandas and Jupyter Notebook!

# %% [markdown]
# Today we're going to learn how to read in a csv file, create a dataframe, identify different ways it may be dirty and learn some techniques for cleaning up our data set.

# %% [markdown]
# karrie.anne.kehoe@gmail.com/@karriekehoe

# %% [markdown]
# ## Getting to grips with Jupyter Notebook and Pandas

# %% [markdown]
# Jupyter Notebook is an interactive, browser based programing environment. It can be used for multiple programming languages, for writing documentation and visualising data. If you want to learn more about what Jupyter Notebook can read its documentation at http://jupyter-notebook.readthedocs.io/en/latest/notebook.html

# %% [markdown]
# Pandas is a python library, designed for statistical analysis. It's very flexible, easy to use and has a range of useful built in functions. If you want to learn more about what Pandas can do, you can read its documentation at http://pandas.pydata.org/ or browse the cook book at http://pandas.pydata.org/pandas-docs/version/0.18.1/tutorials.html

# %% [markdown]
# ### Shortcuts:
# * `esc` - takes you into command mode
# * `a` - insert cell above
# * `b` - insert cell below
# * `shift then tab` will show you the documentation for your code
# * `shift and enter` will run your cell
# * ` d d` will delete a cell

# %% [markdown]
# ### Terminology ###

# %% [markdown]
# **Dataframe** - a dataframe is a two dimensional tabular data structure with labeled axes
#
# **Series** - a series is similar to a list, array or a single column within a dataframe

# %% [markdown]
# ## Starting off

# %% [markdown]
# First we need to import Pandas our python library to do so we use the line of code below. We use 'pd' as an alias to make it easier when typing in our code.
# We are going to type
#
# `import pandas as pd`

# %%
import pandas as pd

# %% [markdown]
# Now we create a dataframe and read in our csv.
#
# `df = pd.read_csv('filepath')`

# %%
df = pd.read_csv('/Users/karrie/Desktop/DATA_TRAINING/CIJ_2018/results.csv')

# %% [markdown]
# Let's look at the first ten rows of our data
#
# `df.head(10)`

# %%
df.head(10)
# Out:
#       ECRef               RegulatedEntityName    RegulatedEntityType  \
# 0  C0314887                Vote Leave Limited  Permitted Participant
# 1  C0363977  Plaid Cymru - The Party of Wales        Political Party
# 2  C0395370  Conservative Middle East Council        Regulated Donee
# 3  V0395331                    Bob Stewart MP        Regulated Donee
# 4  C0395341                Stephen Kinnock MP        Regulated Donee
# 5  C0395372                  The Spring Lunch        Regulated Donee
# 6  C0395371              Your Liberal Britain        Regulated Donee
# 7  C0395373                  The Spring Lunch        Regulated Donee
# 8  C0395342                     Tom Watson MP        Regulated Donee
# 9  C0395333  Conservative Middle East Council        Regulated Donee
#
#          Value AcceptedDate AccountingUnitName                 DonorName  \
# 0  £40,000.00    17/06/2106                NaN             Anthony Clake
# 1  £20,000.00    19/12/2018      Central Party       Mr Alun Ffred Jones
# 2  £50,000.00    06/06/2018                NaN             Rosemary Said
# 3   £2,792.00    29/05/2018                NaN  Government of Kazakhstan
# 4   £7,000.00    17/05/2018                NaN           Community Union
# 5   £9,000.00    16/05/2018                NaN              Sun Mark Ltd
# 6  £10,000.00    16/05/2018                NaN            Mark Petterson
# 7   £8,000.00    16/05/2018                NaN          Lorraine Spencer
# 8   £3,000.00    14/05/2018                NaN            No 1 Skip Hire
# 9  £12,500.00    10/05/2018                NaN               Mark Hilton
#
#   AccountingUnitsAsCentralParty IsSponsorship  DonorStatus      ...       \
# 0                         False         False   Individual      ...
# 1                         False         False   Individual      ...
# 2                         False         False   Individual      ...
# 3                         False         False        Other      ...
# 4                         False         False  Trade Union      ...
# 5                         False         False      Company      ...
# 6                         False         False   Individual      ...
# 7                         False         False   Individual      ...
# 8                         False         False      Company      ...
# 9                         False         False   Individual      ...
#
#   IsReportedPrePoll                          ReportingPeriodName IsBequest  \
# 0             False  Referendum on the UK’s membership of the EU     False
# 1               NaN                                      Q4 2017     False
# 2               NaN                                       May-18     False
# 3               NaN                                       May-18     False
# 4               NaN                                       May-18     False
# 5               NaN                                       May-18     False
# 6               NaN                                       May-18     False
# 7               NaN                                       May-18     False
# 8               NaN                                       May-18     False
# 9               NaN                                       May-18     False
#
#   IsAggregation RegulatedEntityId AccountingUnitId  DonorId CampaigningName  \
# 0         False              3945              NaN    77235             NaN
# 1          True                77              NaN    83318             NaN
# 2         False              1390              NaN    68108             NaN
# 3         False              4012              NaN    76273             NaN
# 4         False              4158              NaN    74244             NaN
# 5         False              1621              NaN    84371             NaN
# 6         False              6603              NaN    84370             NaN
# 7         False              1621              NaN    84372             NaN
# 8         False              1846              NaN    84344             NaN
# 9         False              1390              NaN    77412             NaN
#
#     RegisterName IsIrishSource
# 0            NaN         False
# 1  Great Britain         False
# 2  Great Britain         False
# 3  Great Britain         False
# 4  Great Britain         False
# 5  Great Britain         False
# 6  Great Britain         False
# 7  Great Britain         False
# 8  Great Britain         False
# 9  Great Britain         False
#
# [10 rows x 29 columns]

# %% [markdown]
# Next we need to know what data types we're dealing with for each column in our dataframe
#
# `df.dtypes`

# %%
df.dtypes
# Out:
# ECRef                             object
# RegulatedEntityName               object
# RegulatedEntityType               object
# Value                             object
# AcceptedDate                      object
# AccountingUnitName                object
# DonorName                         object
# AccountingUnitsAsCentralParty       bool
# IsSponsorship                       bool
# DonorStatus                       object
# RegulatedDoneeType                object
# CompanyRegistrationNumber         object
# Postcode                          object
# DonationType                      object
# NatureOfDonation                  object
# PurposeOfVisit                    object
# DonationAction                   float64
# ReceivedDate                      object
# ReportedDate                      object
# IsReportedPrePoll                 object
# ReportingPeriodName               object
# IsBequest                           bool
# IsAggregation                       bool
# RegulatedEntityId                  int64
# AccountingUnitId                 float64
# DonorId                            int64
# CampaigningName                   object
# RegisterName                      object
# IsIrishSource                     object
# dtype: object

# %% [markdown]
# We use .shape to find the dimensions of our data
#
# `df.shape`

# %%
df.shape
# Out:
# (18480, 29)

# %% [markdown]
# ## Data Problems:
# * Dates are python objects and not a datetime object
# * Values are python objects and not ints or floats, so we can't perform any calculations on them
# * We need a year column, perhaps even a month column
# * There may be leading or strail spaces in our data

# %% [markdown]
# Before we change anything we're going to create a copy of our dataframe and clean that up
#
# `df2.copy()`

# %%
df2 = df.copy()

# %% [markdown]
# ## Cleaning strings
#
# We need to clean up the value column and convert it to an integer so we can count it. How do we check that it's worked?
#
# `df2['col'] = df2['col'].str.replace('£', '')`

# %%
df2['Value_clean'] = df2['Value'].str.replace('£', '')

# %%
df2.head()
# Out:
#       ECRef               RegulatedEntityName    RegulatedEntityType  \
# 0  C0314887                Vote Leave Limited  Permitted Participant
# 1  C0363977  Plaid Cymru - The Party of Wales        Political Party
# 2  C0395370  Conservative Middle East Council        Regulated Donee
# 3  V0395331                    Bob Stewart MP        Regulated Donee
# 4  C0395341                Stephen Kinnock MP        Regulated Donee
#
#          Value AcceptedDate AccountingUnitName                 DonorName  \
# 0  £40,000.00    17/06/2106                NaN             Anthony Clake
# 1  £20,000.00    19/12/2018      Central Party       Mr Alun Ffred Jones
# 2  £50,000.00    06/06/2018                NaN             Rosemary Said
# 3   £2,792.00    29/05/2018                NaN  Government of Kazakhstan
# 4   £7,000.00    17/05/2018                NaN           Community Union
#
#   AccountingUnitsAsCentralParty IsSponsorship  DonorStatus     ...      \
# 0                         False         False   Individual     ...
# 1                         False         False   Individual     ...
# 2                         False         False   Individual     ...
# 3                         False         False        Other     ...
# 4                         False         False  Trade Union     ...
#
#                            ReportingPeriodName IsBequest IsAggregation  \
# 0  Referendum on the UK’s membership of the EU     False         False
# 1                                      Q4 2017     False          True
# 2                                       May-18     False         False
# 3                                       May-18     False         False
# 4                                       May-18     False         False
#
#   RegulatedEntityId AccountingUnitId DonorId  CampaigningName   RegisterName  \
# 0              3945              NaN   77235              NaN            NaN
# 1                77              NaN   83318              NaN  Great Britain
# 2              1390              NaN   68108              NaN  Great Britain
# 3              4012              NaN   76273              NaN  Great Britain
# 4              4158              NaN   74244              NaN  Great Britain
#
#   IsIrishSource Value_clean
# 0         False  40,000.00
# 1         False  20,000.00
# 2         False  50,000.00
# 3         False   2,792.00
# 4         False   7,000.00
#
# [5 rows x 30 columns]

# %%
df2['Value_clean'] = df2['Value_clean'].str.replace(',', '')
df2['Value_clean'] = df2['Value_clean'].str.replace('.', '')

# %%
df2.head()
# Out:
#       ECRef               RegulatedEntityName    RegulatedEntityType  \
# 0  C0314887                Vote Leave Limited  Permitted Participant
# 1  C0363977  Plaid Cymru - The Party of Wales        Political Party
# 2  C0395370  Conservative Middle East Council        Regulated Donee
# 3  V0395331                    Bob Stewart MP        Regulated Donee
# 4  C0395341                Stephen Kinnock MP        Regulated Donee
#
#          Value AcceptedDate AccountingUnitName                 DonorName  \
# 0  £40,000.00    17/06/2106                NaN             Anthony Clake
# 1  £20,000.00    19/12/2018      Central Party       Mr Alun Ffred Jones
# 2  £50,000.00    06/06/2018                NaN             Rosemary Said
# 3   £2,792.00    29/05/2018                NaN  Government of Kazakhstan
# 4   £7,000.00    17/05/2018                NaN           Community Union
#
#   AccountingUnitsAsCentralParty IsSponsorship  DonorStatus     ...      \
# 0                         False         False   Individual     ...
# 1                         False         False   Individual     ...
# 2                         False         False   Individual     ...
# 3                         False         False        Other     ...
# 4                         False         False  Trade Union     ...
#
#                            ReportingPeriodName IsBequest IsAggregation  \
# 0  Referendum on the UK’s membership of the EU     False         False
# 1                                      Q4 2017     False          True
# 2                                       May-18     False         False
# 3                                       May-18     False         False
# 4                                       May-18     False         False
#
#   RegulatedEntityId AccountingUnitId DonorId  CampaigningName   RegisterName  \
# 0              3945              NaN   77235              NaN            NaN
# 1                77              NaN   83318              NaN  Great Britain
# 2              1390              NaN   68108              NaN  Great Britain
# 3              4012              NaN   76273              NaN  Great Britain
# 4              4158              NaN   74244              NaN  Great Britain
#
#   IsIrishSource Value_clean
# 0         False    4000000
# 1         False    2000000
# 2         False    5000000
# 3         False     279200
# 4         False     700000
#
# [5 rows x 30 columns]

# %% [markdown]
# Now check to see if that worked

# %%
df2.dtypes
# Out:
# ECRef                             object
# RegulatedEntityName               object
# RegulatedEntityType               object
# Value                             object
# AcceptedDate                      object
# AccountingUnitName                object
# DonorName                         object
# AccountingUnitsAsCentralParty       bool
# IsSponsorship                       bool
# DonorStatus                       object
# RegulatedDoneeType                object
# CompanyRegistrationNumber         object
# Postcode                          object
# DonationType                      object
# NatureOfDonation                  object
# PurposeOfVisit                    object
# DonationAction                   float64
# ReceivedDate                      object
# ReportedDate                      object
# IsReportedPrePoll                 object
# ReportingPeriodName               object
# IsBequest                           bool
# IsAggregation                       bool
# RegulatedEntityId                  int64
# AccountingUnitId                 float64
# DonorId                            int64
# CampaigningName                   object
# RegisterName                      object
# IsIrishSource                     object
# Value_clean                       object
# dtype: object

# %% [markdown]
# ## Changing data types
#
# Ok, no luck. We need to explicitly change the data type for the new Value clean column.
#
# `df2['Value_clean'] = pd.to_numeric(df2['Value_clean'])`

# %%
df2['Value_clean'] = pd.to_numeric(df2['Value_clean'])
df2.dtypes
# Out:
# ECRef                             object
# RegulatedEntityName               object
# RegulatedEntityType               object
# Value                             object
# AcceptedDate                      object
# AccountingUnitName                object
# DonorName                         object
# AccountingUnitsAsCentralParty       bool
# IsSponsorship                       bool
# DonorStatus                       object
# RegulatedDoneeType                object
# CompanyRegistrationNumber         object
# Postcode                          object
# DonationType                      object
# NatureOfDonation                  object
# PurposeOfVisit                    object
# DonationAction                   float64
# ReceivedDate                      object
# ReportedDate                      object
# IsReportedPrePoll                 object
# ReportingPeriodName               object
# IsBequest                           bool
# IsAggregation                       bool
# RegulatedEntityId                  int64
# AccountingUnitId                 float64
# DonorId                            int64
# CampaigningName                   object
# RegisterName                      object
# IsIrishSource                     object
# Value_clean                        int64
# dtype: object

# %% [markdown]
# However we need to make sure that we count our donations amount correctly. So let's divide the column by 100.

# %%
df2['Value_clean'] = df2['Value_clean']/100
df2.head()
# Out:
#       ECRef               RegulatedEntityName    RegulatedEntityType  \
# 0  C0314887                Vote Leave Limited  Permitted Participant
# 1  C0363977  Plaid Cymru - The Party of Wales        Political Party
# 2  C0395370  Conservative Middle East Council        Regulated Donee
# 3  V0395331                    Bob Stewart MP        Regulated Donee
# 4  C0395341                Stephen Kinnock MP        Regulated Donee
#
#          Value AcceptedDate AccountingUnitName                 DonorName  \
# 0  £40,000.00    17/06/2106                NaN             Anthony Clake
# 1  £20,000.00    19/12/2018      Central Party       Mr Alun Ffred Jones
# 2  £50,000.00    06/06/2018                NaN             Rosemary Said
# 3   £2,792.00    29/05/2018                NaN  Government of Kazakhstan
# 4   £7,000.00    17/05/2018                NaN           Community Union
#
#   AccountingUnitsAsCentralParty IsSponsorship  DonorStatus     ...      \
# 0                         False         False   Individual     ...
# 1                         False         False   Individual     ...
# 2                         False         False   Individual     ...
# 3                         False         False        Other     ...
# 4                         False         False  Trade Union     ...
#
#                            ReportingPeriodName IsBequest IsAggregation  \
# 0  Referendum on the UK’s membership of the EU     False         False
# 1                                      Q4 2017     False          True
# 2                                       May-18     False         False
# 3                                       May-18     False         False
# 4                                       May-18     False         False
#
#   RegulatedEntityId AccountingUnitId DonorId  CampaigningName   RegisterName  \
# 0              3945              NaN   77235              NaN            NaN
# 1                77              NaN   83318              NaN  Great Britain
# 2              1390              NaN   68108              NaN  Great Britain
# 3              4012              NaN   76273              NaN  Great Britain
# 4              4158              NaN   74244              NaN  Great Britain
#
#   IsIrishSource Value_clean
# 0         False     40000.0
# 1         False     20000.0
# 2         False     50000.0
# 3         False      2792.0
# 4         False      7000.0
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Dropping and re-naming columns
#
# Let's clean up our dataframe a bit by dropping the original Value column - the 1 is the index, so we're saying it's the column with the value Value in the first row
#
# `df2 = df2.drop('Value', 1)`

# %%
df2 = df2.drop('Value', 1)
df2.head()
# Out:
#       ECRef               RegulatedEntityName    RegulatedEntityType  \
# 0  C0314887                Vote Leave Limited  Permitted Participant
# 1  C0363977  Plaid Cymru - The Party of Wales        Political Party
# 2  C0395370  Conservative Middle East Council        Regulated Donee
# 3  V0395331                    Bob Stewart MP        Regulated Donee
# 4  C0395341                Stephen Kinnock MP        Regulated Donee
#
#   AcceptedDate AccountingUnitName                 DonorName  \
# 0   17/06/2106                NaN             Anthony Clake
# 1   19/12/2018      Central Party       Mr Alun Ffred Jones
# 2   06/06/2018                NaN             Rosemary Said
# 3   29/05/2018                NaN  Government of Kazakhstan
# 4   17/05/2018                NaN           Community Union
#
#   AccountingUnitsAsCentralParty IsSponsorship  DonorStatus  \
# 0                         False         False   Individual
# 1                         False         False   Individual
# 2                         False         False   Individual
# 3                         False         False        Other
# 4                         False         False  Trade Union
#
#           RegulatedDoneeType     ...      \
# 0                        NaN     ...
# 1                        NaN     ...
# 2        Members Association     ...
# 3  MP - Member of Parliament     ...
# 4  MP - Member of Parliament     ...
#
#                            ReportingPeriodName IsBequest IsAggregation  \
# 0  Referendum on the UK’s membership of the EU     False         False
# 1                                      Q4 2017     False          True
# 2                                       May-18     False         False
# 3                                       May-18     False         False
# 4                                       May-18     False         False
#
#   RegulatedEntityId AccountingUnitId  DonorId CampaigningName   RegisterName  \
# 0              3945              NaN    77235             NaN            NaN
# 1                77              NaN    83318             NaN  Great Britain
# 2              1390              NaN    68108             NaN  Great Britain
# 3              4012              NaN    76273             NaN  Great Britain
# 4              4158              NaN    74244             NaN  Great Britain
#
#   IsIrishSource Value_clean
# 0         False     40000.0
# 1         False     20000.0
# 2         False     50000.0
# 3         False      2792.0
# 4         False      7000.0
#
# [5 rows x 29 columns]

# %% [markdown]
# Now that's gone, let's rename the Value clean column
#
# `df2 = df2.rename(columns={'old_name': 'new_name'})`

# %%
df2 = df2.rename(columns={'Value_clean': 'Value'})
df2.head()
# Out:
#       ECRef               RegulatedEntityName    RegulatedEntityType  \
# 0  C0314887                Vote Leave Limited  Permitted Participant
# 1  C0363977  Plaid Cymru - The Party of Wales        Political Party
# 2  C0395370  Conservative Middle East Council        Regulated Donee
# 3  V0395331                    Bob Stewart MP        Regulated Donee
# 4  C0395341                Stephen Kinnock MP        Regulated Donee
#
#   AcceptedDate AccountingUnitName                 DonorName  \
# 0   17/06/2106                NaN             Anthony Clake
# 1   19/12/2018      Central Party       Mr Alun Ffred Jones
# 2   06/06/2018                NaN             Rosemary Said
# 3   29/05/2018                NaN  Government of Kazakhstan
# 4   17/05/2018                NaN           Community Union
#
#   AccountingUnitsAsCentralParty IsSponsorship  DonorStatus  \
# 0                         False         False   Individual
# 1                         False         False   Individual
# 2                         False         False   Individual
# 3                         False         False        Other
# 4                         False         False  Trade Union
#
#           RegulatedDoneeType   ...     \
# 0                        NaN   ...
# 1                        NaN   ...
# 2        Members Association   ...
# 3  MP - Member of Parliament   ...
# 4  MP - Member of Parliament   ...
#
#                            ReportingPeriodName IsBequest IsAggregation  \
# 0  Referendum on the UK’s membership of the EU     False         False
# 1                                      Q4 2017     False          True
# 2                                       May-18     False         False
# 3                                       May-18     False         False
# 4                                       May-18     False         False
#
#   RegulatedEntityId AccountingUnitId  DonorId CampaigningName   RegisterName  \
# 0              3945              NaN    77235             NaN            NaN
# 1                77              NaN    83318             NaN  Great Britain
# 2              1390              NaN    68108             NaN  Great Britain
# 3              4012              NaN    76273             NaN  Great Britain
# 4              4158              NaN    74244             NaN  Great Britain
#
#   IsIrishSource    Value
# 0         False  40000.0
# 1         False  20000.0
# 2         False  50000.0
# 3         False   2792.0
# 4         False   7000.0
#
# [5 rows x 29 columns]

# %% [markdown]
# Let's make sure there aren't any trail or leading spaces in the column names, if so this could cause havoc
#
# `df2.columns`

# %%
df2.columns
# Out:
# Index(['ECRef', 'RegulatedEntityName', 'RegulatedEntityType', 'AcceptedDate',
#        'AccountingUnitName', 'DonorName', 'AccountingUnitsAsCentralParty',
#        'IsSponsorship', 'DonorStatus', 'RegulatedDoneeType',
#        'CompanyRegistrationNumber', 'Postcode', 'DonationType',
#        'NatureOfDonation', 'PurposeOfVisit', 'DonationAction', 'ReceivedDate',
#        'ReportedDate', 'IsReportedPrePoll', 'ReportingPeriodName', 'IsBequest',
#        'IsAggregation', 'RegulatedEntityId', 'AccountingUnitId', 'DonorId',
#        'CampaigningName', 'RegisterName', 'IsIrishSource', 'Value'],
#       dtype='object')

# %% [markdown]
# All good, but maybe there are some in the donor names.
#
# `df2['column'].unique()`

# %%
df2['DonorName'].unique()
# Out:
# array([' Anthony Clake', 'Mr Alun Ffred Jones', ' Rosemary Said', ...,
#        'Mr Alex Sobel', 'Mr Mohammed Miah', 'Mr H E Huppert'], dtype=object)

# %% [markdown]
# Yup just like I thought, there is a leading space in Anthony Clarke, we need to fix that. First though we need to make sure that the DonorName is a column of strings, if there are any numeric names in there it'll confuse python and we won't be able to manipulate the column
#
# `df2['column'] = df2['column'].astype(str)`

# %%
df2['DonorName'] = df2['DonorName'].astype(str)

# %% [markdown]
# Ok now we're going to strip out any of those trail spaces
#
# `df2['column']=df2['column'].map(str.strip)`

# %%
df2['DonorName_clean']=df2['DonorName'].map(str.strip)

# %% [markdown]
# Did that work?
#
# `df2[column].unique()`

# %%
df2['DonorName_clean'].unique()
# Out:
# array(['Anthony Clake', 'Mr Alun Ffred Jones', 'Rosemary Said', ...,
#        'Mr Alex Sobel', 'Mr Mohammed Miah', 'Mr H E Huppert'], dtype=object)

# %% [markdown]
# ## Dates and Years
#
# Ok, the reporting periods are pretty messy, so let's create a new column with the year value in there. We can extract that from one of the date columns. To do that we need to import the new library called datetime
#
# `import datetime`

# %%
import datetime

# %% [markdown]
# Now we're going to strip the year from the accepted date and insert the value in a new column called 'Year'
#
# `df2['YEAR'] = pd.DatetimeIndex(df2['AcceptedDate']).year`

# %%
df2['YEAR'] = pd.DatetimeIndex(df2['AcceptedDate']).year

# %% [markdown]
# Did that work? If so let's try do the same for the month value, same formula as year

# %%
df2.head()
# Out:
#       ECRef               RegulatedEntityName    RegulatedEntityType  \
# 0  C0314887                Vote Leave Limited  Permitted Participant
# 1  C0363977  Plaid Cymru - The Party of Wales        Political Party
# 2  C0395370  Conservative Middle East Council        Regulated Donee
# 3  V0395331                    Bob Stewart MP        Regulated Donee
# 4  C0395341                Stephen Kinnock MP        Regulated Donee
#
#   AcceptedDate AccountingUnitName                 DonorName  \
# 0   17/06/2106                NaN             Anthony Clake
# 1   19/12/2018      Central Party       Mr Alun Ffred Jones
# 2   06/06/2018                NaN             Rosemary Said
# 3   29/05/2018                NaN  Government of Kazakhstan
# 4   17/05/2018                NaN           Community Union
#
#   AccountingUnitsAsCentralParty IsSponsorship  DonorStatus  \
# 0                         False         False   Individual
# 1                         False         False   Individual
# 2                         False         False   Individual
# 3                         False         False        Other
# 4                         False         False  Trade Union
#
#           RegulatedDoneeType  ...  IsAggregation RegulatedEntityId  \
# 0                        NaN  ...          False              3945
# 1                        NaN  ...           True                77
# 2        Members Association  ...          False              1390
# 3  MP - Member of Parliament  ...          False              4012
# 4  MP - Member of Parliament  ...          False              4158
#
#   AccountingUnitId DonorId CampaigningName   RegisterName IsIrishSource  \
# 0              NaN   77235             NaN            NaN         False
# 1              NaN   83318             NaN  Great Britain         False
# 2              NaN   68108             NaN  Great Britain         False
# 3              NaN   76273             NaN  Great Britain         False
# 4              NaN   74244             NaN  Great Britain         False
#
#      Value           DonorName_clean  YEAR
# 0  40000.0             Anthony Clake  2106
# 1  20000.0       Mr Alun Ffred Jones  2018
# 2  50000.0             Rosemary Said  2018
# 3   2792.0  Government of Kazakhstan  2018
# 4   7000.0           Community Union  2018
#
# [5 rows x 31 columns]

# %%
df2['MONTH'] = pd.DatetimeIndex(df2['AcceptedDate']).month

# %%
df2.head()
# Out:
#       ECRef               RegulatedEntityName    RegulatedEntityType  \
# 0  C0314887                Vote Leave Limited  Permitted Participant
# 1  C0363977  Plaid Cymru - The Party of Wales        Political Party
# 2  C0395370  Conservative Middle East Council        Regulated Donee
# 3  V0395331                    Bob Stewart MP        Regulated Donee
# 4  C0395341                Stephen Kinnock MP        Regulated Donee
#
#   AcceptedDate AccountingUnitName                 DonorName  \
# 0   17/06/2106                NaN             Anthony Clake
# 1   19/12/2018      Central Party       Mr Alun Ffred Jones
# 2   06/06/2018                NaN             Rosemary Said
# 3   29/05/2018                NaN  Government of Kazakhstan
# 4   17/05/2018                NaN           Community Union
#
#   AccountingUnitsAsCentralParty IsSponsorship  DonorStatus  \
# 0                         False         False   Individual
# 1                         False         False   Individual
# 2                         False         False   Individual
# 3                         False         False        Other
# 4                         False         False  Trade Union
#
#           RegulatedDoneeType  ...  RegulatedEntityId AccountingUnitId DonorId  \
# 0                        NaN  ...               3945              NaN   77235
# 1                        NaN  ...                 77              NaN   83318
# 2        Members Association  ...               1390              NaN   68108
# 3  MP - Member of Parliament  ...               4012              NaN   76273
# 4  MP - Member of Parliament  ...               4158              NaN   74244
#
#   CampaigningName   RegisterName  IsIrishSource    Value  \
# 0             NaN            NaN          False  40000.0
# 1             NaN  Great Britain          False  20000.0
# 2             NaN  Great Britain          False  50000.0
# 3             NaN  Great Britain          False   2792.0
# 4             NaN  Great Britain          False   7000.0
#
#             DonorName_clean  YEAR MONTH
# 0             Anthony Clake  2106     6
# 1       Mr Alun Ffred Jones  2018    12
# 2             Rosemary Said  2018     6
# 3  Government of Kazakhstan  2018     5
# 4           Community Union  2018     5
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Shrinking dataframes
#
# Ok finally let's get rid of some of the columns and make our dataframe a more manageable size
#
# To do this we need a list of column names again

# %%
df2.columns
# Out:
# Index(['ECRef', 'RegulatedEntityName', 'RegulatedEntityType', 'AcceptedDate',
#        'AccountingUnitName', 'DonorName', 'AccountingUnitsAsCentralParty',
#        'IsSponsorship', 'DonorStatus', 'RegulatedDoneeType',
#        'CompanyRegistrationNumber', 'Postcode', 'DonationType',
#        'NatureOfDonation', 'PurposeOfVisit', 'DonationAction', 'ReceivedDate',
#        'ReportedDate', 'IsReportedPrePoll', 'ReportingPeriodName', 'IsBequest',
#        'IsAggregation', 'RegulatedEntityId', 'AccountingUnitId', 'DonorId',
#        'CampaigningName', 'RegisterName', 'IsIrishSource', 'Value',
#        'DonorName_clean', 'YEAR', 'MONTH'],
#       dtype='object')

# %% [markdown]
# Alright let's figure what we need and shrink the dataframe
#
# `df2 = df2[['RegulatedEntityName', 'AcceptedDate', 'DonorName_clean', 'DonorStatus', 'YEAR', 'Value', 'RegulatedEntityType', 'DonorId', 'CampaigningName']]`

# %%
df2 = df2[['RegulatedEntityName', 'AcceptedDate', 'DonorName_clean', 'DonorStatus', 'YEAR', 'Value', 'RegulatedEntityType', 'DonorId', 'CampaigningName']]

# %%
df2.head()
# Out:
#                 RegulatedEntityName AcceptedDate           DonorName_clean  \
# 0                Vote Leave Limited   17/06/2106             Anthony Clake
# 1  Plaid Cymru - The Party of Wales   19/12/2018       Mr Alun Ffred Jones
# 2  Conservative Middle East Council   06/06/2018             Rosemary Said
# 3                    Bob Stewart MP   29/05/2018  Government of Kazakhstan
# 4                Stephen Kinnock MP   17/05/2018           Community Union
#
#    DonorStatus  YEAR    Value    RegulatedEntityType  DonorId CampaigningName
# 0   Individual  2106  40000.0  Permitted Participant    77235             NaN
# 1   Individual  2018  20000.0        Political Party    83318             NaN
# 2   Individual  2018  50000.0        Regulated Donee    68108             NaN
# 3        Other  2018   2792.0        Regulated Donee    76273             NaN
# 4  Trade Union  2018   7000.0        Regulated Donee    74244             NaN

# %% [markdown]
# ## Saving our data
#
# Ok finally let's save our clean for the next class
#
# `df2.to_csv('clean_data.csv', encoding='utf8')`

# %%
df2.to_csv('clean_data.csv', encoding='utf8')
